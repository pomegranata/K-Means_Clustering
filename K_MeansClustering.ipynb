# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
df = pd.read_csv('Documents/dataset/konsumen.csv')
df.head()
# Out:
#    Gaji  Pengeluaran
# 0  2500         1750
# 1  3800         4200
# 2  3900         3800
# 3  4350         5500
# 4  4400         3200

# %%
scaler = StandardScaler()
scaled_df = scaler.fit_transform(df)

# K-Means Clustering
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(scaled_df)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=3, random_state=42)

# %%
# Menambah kolom label hasil clustering ke dataset
df['cluster'] = kmeans.labels_

# Visualisasi hasil clustering
plt.figure(figsize=(8, 6))
plt.scatter(df['Gaji'], df['Pengeluaran'], c=df['cluster'], cmap='viridis')
plt.xlabel('Gaji')
plt.ylabel('Pengeluaran')
plt.title('K-Means Clustering')
plt.show()

print(df)
# Out:
#     Gaji  Pengeluaran  cluster
# 0   2500         1750        1
# 1   3800         4200        1
# 2   3900         3800        1
# 3   4350         5500        1
# 4   4400         3200        1
# 5   5500         5450        1
# 6   5600         5950        1
# 7   5750         4100        1
# 8   6850         6050        2
# 9   6900         8500        0
# 10  7250         9500        0
# 11  7350         6050        2
# 12  7500         8500        0
# 13  7800         9500        0
# 14  8200         8300        0
# 15  8500         6500        2
# 16  8550         8400        0
# 17  8750         6000        2
# 18  9100        10500        0
# 19  9100         8500        0

# %%
X = np.asarray(df)
print(X)
# Out:
# [[ 2500  1750     1]
#  [ 3800  4200     1]
#  [ 3900  3800     1]
#  [ 4350  5500     1]
#  [ 4400  3200     1]
#  [ 5500  5450     1]
#  [ 5600  5950     1]
#  [ 5750  4100     1]
#  [ 6850  6050     2]
#  [ 6900  8500     0]
#  [ 7250  9500     0]
#  [ 7350  6050     2]
#  [ 7500  8500     0]
#  [ 7800  9500     0]
#  [ 8200  8300     0]
#  [ 8500  6500     2]
#  [ 8550  8400     0]
#  [ 8750  6000     2]
#  [ 9100 10500     0]
#  [ 9100  8500     0]]

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(X)
print(kmeans.cluster_centers_)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# [[7.98750000e+03 8.02500000e+03 6.66666667e-01]
#  [4.47500000e+03 4.24375000e+03 1.00000000e+00]]

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['Gaji'], df['Pengeluaran'], c=kmeans.labels_, cmap='rainbow')
plt.xlabel('Gaji')
plt.ylabel('Pengeluaran')
plt.title('Scatter Plot')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['Gaji'], df['Pengeluaran'], c=kmeans.labels_, cmap='rainbow')
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], color='black')
plt.xlabel('Gaji')
plt.ylabel('Pengeluaran')
plt.title('Centroid')
plt.show()
